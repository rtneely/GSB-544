# %%
import pandas as pd
import plotnine as p9
from plotnine import *
import numpy as np

# %%
df = pd.read_csv("q1data.csv")
print(df)
# Out:
#       income  life_exp  population  year  ... four_regions               six_regions       eight_regions           world_bank_region
# 0     1910.0      61.0  29200000.0  2010  ...         asia                south_asia           asia_west                  South Asia
# 1    11100.0      78.1   2950000.0  2010  ...       europe       europe_central_asia         europe_east       Europe & Central Asia
# 2    11100.0      74.7  36000000.0  2010  ...       africa  middle_east_north_africa        africa_north  Middle East & North Africa
# 3    46900.0      81.9     84500.0  2010  ...       europe       europe_central_asia         europe_west       Europe & Central Asia
# 4     7680.0      60.8  23400000.0  2010  ...       africa        sub_saharan_africa  africa_sub_saharan          Sub-Saharan Africa
# ..       ...       ...         ...   ...  ...          ...                       ...                 ...                         ...
# 192  20400.0      75.4  28400000.0  2010  ...     americas                   america       america_south   Latin America & Caribbean
# 193   5350.0      73.3  88000000.0  2010  ...         asia         east_asia_pacific   east_asia_pacific         East Asia & Pacific
# 194   4700.0      67.8  23200000.0  2010  ...         asia  middle_east_north_africa           asia_west  Middle East & North Africa
# 195   3200.0      57.5  13600000.0  2010  ...       africa        sub_saharan_africa  africa_sub_saharan          Sub-Saharan Africa
# 196   2560.0      54.4  12700000.0  2010  ...       africa        sub_saharan_africa  africa_sub_saharan          Sub-Saharan Africa
#
# [197 rows x 9 columns]
#       income  life_exp  population  year  ... four_regions               six_regions       eight_regions           world_bank_region
# 0     1910.0      61.0  29200000.0  2010  ...         asia                south_asia           asia_west                  South Asia
# 1    11100.0      78.1   2950000.0  2010  ...       europe       europe_central_asia         europe_east       Europe & Central Asia
# 2    11100.0      74.7  36000000.0  2010  ...       africa  middle_east_north_africa        africa_north  Middle East & North Africa
# 3    46900.0      81.9     84500.0  2010  ...       europe       europe_central_asia         europe_west       Europe & Central Asia
# 4     7680.0      60.8  23400000.0  2010  ...       africa        sub_saharan_africa  africa_sub_saharan          Sub-Saharan Africa
# ..       ...       ...         ...   ...  ...          ...                       ...                 ...                         ...
# 192  20400.0      75.4  28400000.0  2010  ...     americas                   america       america_south   Latin America & Caribbean
# 193   5350.0      73.3  88000000.0  2010  ...         asia         east_asia_pacific   east_asia_pacific         East Asia & Pacific
# 194   4700.0      67.8  23200000.0  2010  ...         asia  middle_east_north_africa           asia_west  Middle East & North Africa
# 195   3200.0      57.5  13600000.0  2010  ...       africa        sub_saharan_africa  africa_sub_saharan          Sub-Saharan Africa
# 196   2560.0      54.4  12700000.0  2010  ...       africa        sub_saharan_africa  africa_sub_saharan          Sub-Saharan Africa
#
# [197 rows x 9 columns]

# %%
region_colors = {'africa':'deepskyblue', 'americas':'lime', 'asia':'indianred', 'europe':'gold'}

(ggplot(df, aes(x='income',
y='life_exp',
size='population',
fill='four_regions',
label='country'))+
geom_text(aes(x=700, y=38, label='2010'), size=100, color='lightgray',ha='left',va='bottom')+
geom_point(color='black', stroke=0.3, alpha=0.7)+
labs(x="Income", y="Life Expectancy",fill="World Regions", size='Population')+
scale_x_continuous(limits = (500,64000),breaks=[500, 1000, 2000, 4000, 8000, 16000, 32000, 64000],trans='log2',labels=[500, 1000, 2000, 4000, 8000, '16k', '32k', '64k'])+
scale_y_continuous(limits=(20,90),breaks=range(20,91, 10))+
scale_fill_manual(values=region_colors)+
scale_size_continuous(range=(0, 22))+
theme(panel_grid_major=element_line(color='lightgray'),
panel_grid_minor=element_blank(),
panel_background=element_blank())
)
# Out:
# C:\Users\rtnee\anaconda3\Lib\site-packages\plotnine\layer.py:364: PlotnineWarning: geom_point : Removed 11 rows containing missing values.
