# %% [raw]
# ---
# title: Take Home Final Regression
# author: Ryan Neely
# format:
#     html:
#         toc: true
#         code-fold: false
#         embed-resources: true
#         echo: true
# ---

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %%
train_df = pd.read_csv('train_new.csv')
train_df.head()
# Out:
#    SalePrice        PID  Lot Frontage  ...  Pool Area Yr Sold Sale Type
# 0     159000  531363010          80.0  ...          0    2009        WD
# 1     271900  906203120          90.0  ...          0    2009        WD
# 2     137500  916176030           NaN  ...          0    2009       COD
# 3     248500  528180130          48.0  ...          0    2009        WD
# 4     167000  528290030          61.0  ...          0    2009        WD
#
# [5 rows x 25 columns]

# %%
test_df = pd.read_csv('test_new.csv')
test_df.head()
# Out:
#          PID  Lot Frontage  Lot Area  ... Pool Area Yr Sold Sale Type
# 0  907135180            60      8070  ...         0    2007        WD
# 1  528181040            40      6792  ...         0    2006       New
# 2  528175010            44      6371  ...         0    2010       New
# 3  531379030            70      8304  ...         0    2006        WD
# 4  923275090            37      6951  ...         0    2008        WD
#
# [5 rows x 24 columns]

# %%
train_df = train_df.dropna()
test_df = test_df.dropna()

# %%
train_df['LogSalePrice'] = np.log(train_df['SalePrice'])

# %%
X_train = train_df.drop(['LogSalePrice','SalePrice','PID'],axis=1)
y_train = train_df['LogSalePrice']

# %%
ct = ColumnTransformer(
    [
        ('standardize', StandardScaler(), make_column_selector(dtype_include=np.number)),
        ('dummify', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), make_column_selector(dtype_include=object))
    ],
    remainder= 'passthrough'
)

# %%
lr_pipline = Pipeline(
    [
        ('preprocessing', ct),
        ('regression', LinearRegression())
    ]
)

lr_model = lr_pipline.fit(X_train,y_train)

-cross_val_score(lr_pipline, X_train, y_train, cv = 5, scoring = "neg_root_mean_squared_error").mean().round(2)
# Out:
# 7063705613.12

# %%
ridge_pipeline = Pipeline(
    [
        ('preprocessing', ct),
        ('ridge', Ridge())
    ]
)

alpha_values = [0.001, 0.01, 0.1, 1, 10]
alphas = {'ridge__alpha': alpha_values}

gscv = GridSearchCV(ridge_pipeline, alphas, cv=5, scoring='neg_root_mean_squared_error')
gscv.fit(X_train, y_train)


best_model_ridge = gscv.best_estimator_
best_lambda_ridge = gscv.best_params_['ridge__alpha']
print(f"Best lambda: {best_lambda_ridge}")
print(f"Best Model RMSE: {-gscv.best_score_}")
# Out:
# Best lambda: 0.1
# Best Model RMSE: 0.15307762364212502
# Best lambda: 0.1
# Best Model RMSE: 0.15307762364212502

# %%
elastic_pipeline = Pipeline(
    [("preprocessing", ct),
     ("elastic", ElasticNet())]
)

params = {
    "elastic__alpha": [0.001, 0.01, 0.1, 1, 10],
    "elastic__l1_ratio": [0.1, 0.3, 0.5, 0.7, 0.9, 1.0]
}

gscv = GridSearchCV(elastic_pipeline, params, cv=5, scoring='neg_root_mean_squared_error')
gscv.fit(X_train, y_train)

best_elastic_model = gscv.best_estimator_
best_param_elastic = gscv.best_params_

best_score = gscv.best_score_

print(f"Best Parameters: {best_param_elastic}")
print(f"Best Model RMSE: {-gscv.best_score_}")
# Out:
# Best Parameters: {'elastic__alpha': 0.001, 'elastic__l1_ratio': 0.3}
# Best Model RMSE: 0.15263411303401705
# Best Parameters: {'elastic__alpha': 0.001, 'elastic__l1_ratio': 0.3}
# Best Model RMSE: 0.15263411303401705

# %%
feature_names = best_elastic_model.named_steps['preprocessing'].get_feature_names_out()
elastic_coefs = best_elastic_model.named_steps['elastic'].coef_

coef_df = pd.DataFrame({'Feature': feature_names, 'Coefficient': elastic_coefs})
coef_df.sort_values(by = 'Coefficient', key = abs, ascending= False)

coefficients = dict(zip(feature_names, elastic_coefs))
sorted_coefficients = dict(sorted(coefficients.items(), key=lambda item: abs(item[1]), reverse=False))
sorted_coefficients
# Out:
# {'standardize__TotRms AbvGrd': 0.0,
#  'dummify__Street_Grvl': -0.0,
#  'dummify__Street_Pave': 0.0,
#  'dummify__Neighborhood_Blmngtn': -0.0,
#  'dummify__Neighborhood_Blueste': 0.0,
#  'dummify__Neighborhood_Gilbert': -0.0,
#  'dummify__Neighborhood_Mitchel': -0.0,
#  'dummify__Neighborhood_NPkVill': -0.0,
#  'dummify__Neighborhood_Sawyer': 0.0,
#  'dummify__Bldg Type_TwnhsE': -0.0,
#  'dummify__House Style_1.5Fin': 0.0,
#  'dummify__House Style_1.5Unf': -0.0,
#  'dummify__House Style_2.5Unf': -0.0,
#  'dummify__Roof Style_Gambrel': 0.0,
#  'dummify__Roof Style_Mansard': -0.0,
#  'dummify__Roof Style_Shed': -0.0,
#  'dummify__Heating_OthW': -0.0,
#  'dummify__Electrical_FuseA': 0.0,
#  'dummify__Electrical_FuseP': -0.0,
#  'dummify__Electrical_Mix': -0.0,
#  'dummify__Functional_Maj1': -0.0,
#  'dummify__Functional_Mod': 0.0,
#  'dummify__Functional_Sev': -0.0,
#  'dummify__Sale Type_CWD': -0.0,
#  'dummify__Sale Type_Con': 0.0,
#  'dummify__Sale Type_ConLI': -0.0,
#  'dummify__Sale Type_ConLw': 0.0,
#  'dummify__Sale Type_Oth': -0.0,
#  'dummify__Sale Type_VWD': 0.0,
#  'dummify__Neighborhood_NAmes': -0.0028471481134724635,
#  'dummify__House Style_2.5Fin': -0.003068326381244123,
#  'standardize__Yr Sold': -0.003212539525603832,
#  'dummify__Roof Style_Gable': -0.004932003531141564,
#  'standardize__Lot Frontage': -0.00554310102864812,
#  'dummify__Electrical_FuseF': -0.00559780456757295,
#  'dummify__Neighborhood_SWISU': -0.00603519876166552,
#  'standardize__Bedroom AbvGr': -0.009685899821311753,
#  'standardize__Half Bath': 0.01012797635029138,
#  'dummify__Sale Type_New': 0.010343257044824729,
#  'dummify__Heating_Wall': -0.010565301286265077,
#  'standardize__Pool Area': -0.01119912542543459,
#  'dummify__Roof Style_Hip': 0.012726965752481133,
#  'dummify__Neighborhood_Greens': 0.012959210611057629,
#  'dummify__Sale Type_WD': 0.015079596771098762,
#  'dummify__House Style_SLvl': 0.01527776258887341,
#  'dummify__Roof Style_Flat': 0.01653139964104749,
#  'standardize__Lot Area': 0.018385705220953643,
#  'standardize__Screen Porch': 0.020139438068844225,
#  'dummify__Neighborhood_CollgCr': 0.02054185938522822,
#  'dummify__Bldg Type_Duplex': -0.02183197150659646,
#  'dummify__Neighborhood_ClearCr': 0.022162968779555012,
#  'dummify__Sale Type_ConLD': -0.02366835448107964,
#  'dummify__Neighborhood_SawyerW': -0.023681337529550494,
#  'dummify__Functional_Min1': 0.024428543560330973,
#  'standardize__Full Bath': 0.025504556010641756,
#  'dummify__Electrical_SBrkr': 0.025802753587834622,
#  'dummify__Functional_Min2': 0.02912927176633687,
#  'dummify__Neighborhood_NWAmes': -0.03475197455210356,
#  'dummify__House Style_1Story': 0.03724198254102613,
#  'dummify__Sale Type_COD': -0.03804133792027393,
#  'dummify__Neighborhood_BrDale': -0.03946792671955672,
#  'dummify__House Style_2Story': -0.04644584386416908,
#  'standardize__Overall Cond': 0.04827581841751952,
#  'dummify__Functional_Typ': 0.048462334557749176,
#  'dummify__Heating_GasA': 0.04877507722283408,
#  'dummify__Central Air_Y': 0.05127391119383841,
#  'dummify__Neighborhood_BrkSide': -0.05143852197370653,
#  'dummify__Central Air_N': -0.05478590671587243,
#  'dummify__Heating_Grav': -0.05493138274775447,
#  'dummify__House Style_SFoyer': 0.06222583449392263,
#  'dummify__Neighborhood_Timber': 0.0693099508670006,
#  'dummify__Bldg Type_2fmCon': 0.07570506443586945,
#  'dummify__Neighborhood_Somerst': 0.07784983171853642,
#  'dummify__Neighborhood_Edwards': -0.08174649551956593,
#  'dummify__Neighborhood_OldTown': -0.08329697150104058,
#  'dummify__Bldg Type_1Fam': 0.08935928502547386,
#  'standardize__Year Built': 0.09427030271553642,
#  'dummify__Bldg Type_Twnhs': -0.09660263235674478,
#  'dummify__Neighborhood_MeadowV': -0.0995038365377116,
#  'dummify__Heating_GasW': 0.10379165719552974,
#  'dummify__Functional_Maj2': -0.1049168031398222,
#  'dummify__Neighborhood_Veenker': 0.12009776912082475,
#  'dummify__Neighborhood_NoRidge': 0.12871855938351162,
#  'dummify__Neighborhood_IDOTRR': -0.1299022487687883,
#  'standardize__Overall Qual': 0.13421949411608594,
#  'dummify__Neighborhood_Crawfor': 0.13765368444557577,
#  'standardize__Gr Liv Area': 0.15546308950227805,
#  'dummify__Neighborhood_StoneBr': 0.17079001471783253,
#  'dummify__Neighborhood_NridgHt': 0.18526958194818688,
#  'dummify__Functional_Sal': -0.3799573592561003}

# %%
X_test = test_df.drop(['PID'], axis=1)

# %%
elastic_pipeline = Pipeline(
    [("preprocessing", ct),
     ("elastic", ElasticNet(alpha=0.001, l1_ratio=0.3))]
)

elastic_model = elastic_pipeline.fit(X_train,y_train)

y_pred = elastic_model.predict(X_test)

y_pred = np.exp(y_pred)

final_results_elastic = pd.DataFrame({'PID':test_df['PID'],'SalePrice':y_pred})
final_results_elastic
# Out:
#            PID      SalePrice
# 0    907135180  125954.446641
# 1    528181040  219217.630869
# 2    528175010  218565.801246
# 3    531379030  185684.008740
# 4    923275090  128637.782359
# ..         ...            ...
# 600  528174060  179479.533565
# 601  903400180  172523.742471
# 602  903227150  129953.501486
# 603  909250070  161321.804700
# 604  909425180  199235.166063
#
# [605 rows x 2 columns]

# %%
final_results_elastic.to_csv('final_results_elastic.csv',index=False)
